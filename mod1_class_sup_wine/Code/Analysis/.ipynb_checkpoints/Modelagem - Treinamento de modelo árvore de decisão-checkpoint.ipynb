# %% [markdown]
# # Utilizar a base de dados normalizados para treinar um modelo de árvore de decisão utilizando o sklearn.
#
# ## Definição de pronto
#
# ### Normalizador desenvolvido no ambiente
#
# ## Definição de entregue
#
# ### Notebook fazendo a avaliação

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn import model_selection
from sklearn import linear_model as lm
from sklearn import preprocessing
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# Atenção: Este notebook foi executado em ambiente linux. Caso esteja executando em ambiente windows
# descomentar as duas próximas linhas abaixo

#import os
#os.environ['PATH'] = os.environ['PATH'] + ';C:/Program Files (x86)/Graphviz2.38/bin'

pd.set_option("display.precision", 2)

feature_norm  = False

target_variable = ['quality']

classifier_variables = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
                      'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
                      'pH', 'sulphates', 'alcohol',]

# %%
# %run functions.ipynb

# %% [markdown]
# ### Carregando a base processada

# %%
df_wine = pd.read_parquet("../../Data/Processed/wine/df_wine.parquet")
print(df_wine.shape)
print(df_wine.columns)
df_wine.head()
# Out:
# (6497, 13)
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# index
# 0                7.4              0.70         0.00             1.9
# 1                7.8              0.88         0.00             2.6
# 2                7.8              0.76         0.04             2.3
# 3               11.2              0.28         0.56             1.9
# 4                7.4              0.70         0.00             1.9
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# index
# 0           0.08                 11.0                  34.0      1.0  3.51
# 1           0.10                 25.0                  67.0      1.0  3.20
# 2           0.09                 15.0                  54.0      1.0  3.26
# 3           0.07                 17.0                  60.0      1.0  3.16
# 4           0.08                 11.0                  34.0      1.0  3.51
#
#        sulphates  alcohol  quality  type
# index
# 0           0.56      9.4        5     1
# 1           0.68      9.8        5     1
# 2           0.65      9.8        5     1
# 3           0.58      9.8        6     1
# 4           0.56      9.4        5     1

# %% [markdown]
# ### Descrição dos Dados

# %%
df_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        6497.00           6497.00      6497.00         6497.00
# mean            7.22              0.34         0.32            5.44
# std             1.30              0.16         0.15            4.76
# min             3.80              0.08         0.00            0.60
# 25%             6.40              0.23         0.25            1.80
# 50%             7.00              0.29         0.31            3.00
# 75%             7.70              0.40         0.39            8.10
# max            15.90              1.58         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# count   6.50e+03              6497.00               6497.00  6.50e+03
# mean    5.60e-02                30.53                115.74  9.95e-01
# std     3.50e-02                17.75                 56.52  3.00e-03
# min     9.00e-03                 1.00                  6.00  9.87e-01
# 25%     3.80e-02                17.00                 77.00  9.92e-01
# 50%     4.70e-02                29.00                118.00  9.95e-01
# 75%     6.50e-02                41.00                156.00  9.97e-01
# max     6.11e-01               289.00                440.00  1.04e+00
#
#             pH  sulphates  alcohol  quality     type
# count  6497.00    6497.00  6497.00  6497.00  6497.00
# mean      3.22       0.53    10.49     5.82     0.25
# std       0.16       0.15     1.19     0.87     0.43
# min       2.72       0.22     8.00     3.00     0.00
# 25%       3.11       0.43     9.50     5.00     0.00
# 50%       3.21       0.51    10.30     6.00     0.00
# 75%       3.32       0.60    11.30     6.00     0.00
# max       4.01       2.00    14.90     9.00     1.00

# %% [markdown]
# ### Normalizando os dados

# %%
df_wine[classifier_variables] = preprocessing.power_transform(df_wine[classifier_variables], method='yeo-johnson')
# Out:
# /home/marcelo/Documentos/infnet/conda/conda_env/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %% [markdown]
# #### Problema reportado no método yeo-johnson
#
# https://github.com/scikit-learn/scikit-learn/issues/14959

# %% [markdown]
# ### Ajuste dos dados para o treinamento

# %%
# Configurando o Pipeline
X = df_wine[classifier_variables].values
Y = df_wine[target_variable].values
idx = Y > 5
classes=['baixa qualidade','alta qualidade']
Y[idx] = 1
Y[~idx]= 0

# Dividir 20% dos dados para o conjunto out-of-sample de teste
Xtrain, Xtest, Ytrain, Ytest = model_selection.train_test_split(X,
                                                                Y,
                                                                test_size=0.2,
                                                                random_state=0,
                                                                stratify=Y)

# Objeto de validacao cruzada
cvfold = model_selection.StratifiedKFold(n_splits = 10, random_state = 0, shuffle=True)

print(len(Xtrain))

print(len(Xtest))
# Out:
# 5197
# 1300

# %% [markdown]
# ### Pipeline de Treinamento

# %%
# Configurando o Pipeline
conf_train_pipe = [
    ('Scaler', StandardScaler()),
    ('Model', tree.DecisionTreeClassifier(random_state=0)),
]

# Criando o Pipeline
model_pipe = pipeline.Pipeline(conf_train_pipe)

param_grid = {
    'Model__max_depth': [4,5,6,8,10,12],
}

model_pipe = model_selection.GridSearchCV(model_pipe, param_grid,
                                     scoring=None,
                                     cv=cvfold)

model_pipe.fit(Xtrain, Ytrain)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=0, shuffle=True),
#              estimator=Pipeline(steps=[('Scaler', StandardScaler()),
#                                        ('Model',
#                                         DecisionTreeClassifier(random_state=0))]),
#              param_grid={'Model__max_depth': [4, 5, 6, 8, 10, 12]})

# %% [markdown]
# ### Curvas de Aprendizado

# %%
plt.figure()

scorer = metrics.make_scorer(metrics.accuracy_score)

title = "Curva de Aprendizado (Árvore de decisão)"
estimator = tree.DecisionTreeClassifier(random_state=0)
plot_learning_curve(estimator, title, Xtrain, Ytrain, ax=plt.gca(),
                    cv=cvfold.split(Xtrain, Ytrain, groups=Ytrain),
                    scoring=scorer, n_jobs=3)

# %% [markdown]
# ### Estimativa do modelo treinado

# %%
Yhat = model_pipe.predict_proba(X)[:,1]
Ypred= model_pipe.predict(X)
print('Yhat.shape:', Yhat.shape)
print('Ypred.shape:', Ypred.shape)
# Out:
# Yhat.shape: (6497,)
# Ypred.shape: (6497,)

# %% [markdown]
# ### Distribuição das estimativas do modelo utilizando o seaborn

# %%
for i in range(len(classes)):
    # 2 Classes case
    sns.distplot(Yhat[Y[:,0] == i], label=classes[i])

plt.title('Árvore de Decisão')
plt.ylabel('Densidade Estimada KDE')
plt.xlabel('Probabilidade Vinho Alta Qualidade')
plt.grid()
plt.legend()

# %% [markdown]
# ### Curva ROC

# %%
# help(metrics.roc_curve)
plt.figure()
fpr, tpr, thr = metrics.roc_curve(Y, Yhat)
auc = metrics.roc_auc_score(Y, Yhat)
plt.plot(fpr, tpr, '-', lw=2, label='AUC: %.2f'%(auc))
plt.legend()
plt.title('Classificador Vinhos de Alta Qualidade')
plt.grid()
plt.xlabel('Taxa de Falso Alarme')
plt.ylabel('Taxa de Detecção')
# Out:
# Text(0, 0.5, 'Taxa de Detecção')

# %% [markdown]
# **Pela curva ROC poderíamos escolher uma taxa de detecção (sensibilidade) de aproximadamente 90% que teríamos  aproximadamente 10% de falsos positivos (especificidade).**

# %% [markdown]
# ### Matriz de Confusão

# %%
col_names = ['Modelo ' + s for s in classes]
idx_names = ['Real ' + s for s in classes]

cmat = metrics.confusion_matrix(Y, Ypred)
cmat = pd.DataFrame(cmat, index=idx_names,
                              columns=col_names)
cmat['Real Total'] = cmat.sum(axis=1)
cmat.loc['Modelo Total',:] = cmat.sum(axis=0)
cmat = cmat.astype(int)
cmat
# Out:
#                       Modelo baixa qualidade  Modelo alta qualidade  \
# Real baixa qualidade                    2060                    324
# Real alta qualidade                      337                   3776
# Modelo Total                            2397                   4100
#
#                       Real Total
# Real baixa qualidade        2384
# Real alta qualidade         4113
# Modelo Total                6497

# %% [markdown]
# ### Relatório de Classificação

# %%
print(metrics.classification_report(Y, Ypred, target_names=classes))
# Out:
#                  precision    recall  f1-score   support
#
# baixa qualidade       0.86      0.86      0.86      2384
#  alta qualidade       0.92      0.92      0.92      4113
#
#        accuracy                           0.90      6497
#       macro avg       0.89      0.89      0.89      6497
#    weighted avg       0.90      0.90      0.90      6497

# %% [markdown]
# ### Scores da Validação Cruzada

# %%
print(model_pipe.cv_results_)
print('Treino')

# model_pipe.cv_results_ não apresentou média e desvio de treino. Não consegui achar ou entender o motivo.
#print('\tScore:', np.mean(model_pipe.cv_results_['mean_train_score']),
#      '+-'     , np.mean(model_pipe.cv_results_['std_train_score']))
print('Teste')
print('\tScore:', np.mean(model_pipe.cv_results_['mean_test_score']),
       '+-'     , np.mean(model_pipe.cv_results_['std_test_score']))
# Out:
# {'mean_fit_time': array([0.01059439, 0.01147003, 0.0133379 , 0.01699932, 0.02046213,
#        0.02331481]), 'std_fit_time': array([1.20770367e-03, 5.37583725e-05, 1.58275958e-04, 6.16849318e-05,
#        1.23518690e-04, 1.01665386e-03]), 'mean_score_time': array([0.00068743, 0.00060163, 0.00061202, 0.00061555, 0.00062823,
#        0.00068445]), 'std_score_time': array([8.21604434e-05, 1.50899185e-05, 2.50906529e-05, 2.29047675e-05,
#        1.13878258e-05, 1.06337830e-04]), 'param_Model__max_depth': masked_array(data=[4, 5, 6, 8, 10, 12],
#              mask=[False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'Model__max_depth': 4}, {'Model__max_depth': 5}, {'Model__max_depth': 6}, {'Model__max_depth': 8}, {'Model__max_depth': 10}, {'Model__max_depth': 12}], 'split0_test_score': array([0.72307692, 0.71923077, 0.74423077, 0.72307692, 0.72692308,
#        0.75961538]), 'split1_test_score': array([0.73846154, 0.73269231, 0.74230769, 0.73846154, 0.75192308,
#        0.74423077]), 'split2_test_score': array([0.76730769, 0.77307692, 0.775     , 0.75      , 0.775     ,
#        0.775     ]), 'split3_test_score': array([0.72307692, 0.74807692, 0.75      , 0.76153846, 0.75576923,
#        0.74615385]), 'split4_test_score': array([0.73461538, 0.72884615, 0.72884615, 0.74807692, 0.72115385,
#        0.73461538]), 'split5_test_score': array([0.76346154, 0.75192308, 0.75192308, 0.71730769, 0.75      ,
#        0.725     ]), 'split6_test_score': array([0.75      , 0.76346154, 0.76346154, 0.73653846, 0.74807692,
#        0.74423077]), 'split7_test_score': array([0.75529865, 0.74373796, 0.7495183 , 0.73795761, 0.73603083,
#        0.7495183 ]), 'split8_test_score': array([0.7495183 , 0.74566474, 0.74566474, 0.761079  , 0.76493256,
#        0.76300578]), 'split9_test_score': array([0.75337187, 0.76685934, 0.76300578, 0.75529865, 0.78034682,
#        0.78805395]), 'mean_test_score': array([0.74581888, 0.74735697, 0.75139581, 0.74293353, 0.75101564,
#        0.75294242]), 'std_test_score': array([0.01471447, 0.01639308, 0.01232293, 0.01428745, 0.01832774,
#        0.01786452]), 'rank_test_score': array([5, 4, 2, 6, 3, 1], dtype=int32)}
# Treino
# Teste
# 	Score: 0.7485772071537968 +- 0.015651696008692748

# %% [markdown]
# ### Ponto de Calibração

# %%
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

# Calibrado com Sigmmoide
calib_sigmoid = CalibratedClassifierCV(model_pipe, cv=None, method='sigmoid')
calib_sigmoid.fit(X,Y)
Ypred_calib = calib_sigmoid.predict(X)
Yhat_calib  = calib_sigmoid.predict_proba(X)[:,1]


# Modelo perfeito
plt.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")

# Modelo logistico puro
clf_score = metrics.brier_score_loss(Y, Yhat, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Y, Yhat, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="A.D. (%1.3f)" %clf_score)

# Modelo calibrado
clf_score = metrics.brier_score_loss(Y, Yhat_calib, pos_label=1)
fraction_of_positives, mean_predicted_value = calibration_curve(Y, Yhat_calib, n_bins=10)
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="Calibrado (%1.3f)" %clf_score)

plt.ylabel("Fração de Positivos Classificados")
plt.xlabel("Valor Médio Previsto de Positivos")
plt.ylim([-0.05, 1.05])
plt.title('Curvas de Calibração')
plt.legend()
plt.grid()
# Out:
# /home/marcelo/Documentos/infnet/conda/conda_env/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# ### Distribuição Calibrada

# %%
for i in range(len(classes)):
    # 2 Classes case
    sns.distplot(Yhat_calib[Y[:,0] == i], label=classes[i])

plt.title('Árvore de Decisão Calibrada')
plt.ylabel('Densidade Estimada KDE')
plt.xlabel('Probabilidade Vinho Alta Qualidade')
plt.grid()
plt.legend()

# %% [markdown]
# ### ROC Calibrada

# %%
# help(metrics.roc_curve)
plt.figure()
fpr, tpr, thr = metrics.roc_curve(Y, Yhat_calib)
auc = metrics.roc_auc_score(Y, Yhat_calib)
plt.plot(fpr, tpr, '-', lw=2, label='AUC: %.2f'%(auc))
plt.legend()
plt.title('Classificador Vinhos de Alta Qualidade')
plt.grid()
plt.xlabel('Taxa de Falso Alarme')
plt.ylabel('Taxa de Detecção')
# Out:
# Text(0, 0.5, 'Taxa de Detecção')

# %% [markdown]
# ### Diagrama com a Árvore

# %%
from sklearn import tree

clf_tree = model_pipe.best_estimator_.steps[1][1]

tree.plot_tree( clf_tree
              , feature_names=classifier_variables
              , class_names=classes
              , precision=2
              , filled=True
              , proportion=True
              , rounded=True)
# Out:
# [Text(204.7602329799107, 209.07692307692307, 'alcohol <= 0.19\ngini = 0.46\nsamples = 100.0%\nvalue = [0.37, 0.63]\nclass = alta qualidade'),
#  Text(118.91221464082791, 192.35076923076923, 'volatile acidity <= -0.12\ngini = 0.5\nsamples = 56.9%\nvalue = [0.52, 0.48]\nclass = baixa qualidade'),
#  Text(52.39317674512987, 175.62461538461537, 'volatile acidity <= -0.71\ngini = 0.46\nsamples = 26.8%\nvalue = [0.35, 0.65]\nclass = alta qualidade'),
#  Text(18.572635957792208, 158.89846153846153, 'free sulfur dioxide <= -1.17\ngini = 0.37\nsamples = 13.4%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(3.261038961038961, 142.1723076923077, 'chlorides <= -0.46\ngini = 0.48\nsamples = 0.6%\nvalue = [0.59, 0.41]\nclass = baixa qualidade'),
#  Text(1.6305194805194805, 125.44615384615385, 'pH <= 1.65\ngini = 0.22\nsamples = 0.3%\nvalue = [0.88, 0.12]\nclass = baixa qualidade'),
#  Text(1.087012987012987, 108.72, 'alcohol <= 0.11\ngini = 0.12\nsamples = 0.3%\nvalue = [0.93, 0.07]\nclass = baixa qualidade'),
#  Text(0.5435064935064935, 91.99384615384615, 'gini = 0.0\nsamples = 0.3%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(1.6305194805194805, 91.99384615384615, 'chlorides <= -0.63\ngini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(1.087012987012987, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(2.174025974025974, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(2.174025974025974, 108.72, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(4.891558441558441, 125.44615384615385, 'residual sugar <= -0.71\ngini = 0.43\nsamples = 0.3%\nvalue = [0.31, 0.69]\nclass = alta qualidade'),
#  Text(4.348051948051948, 108.72, 'residual sugar <= -1.06\ngini = 0.47\nsamples = 0.2%\nvalue = [0.62, 0.38]\nclass = baixa qualidade'),
#  Text(3.8045454545454547, 91.99384615384615, 'free sulfur dioxide <= -1.71\ngini = 0.38\nsamples = 0.1%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(3.261038961038961, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(4.348051948051948, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(4.891558441558441, 91.99384615384615, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(5.4350649350649345, 108.72, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(33.88423295454545, 142.1723076923077, 'sulphates <= -0.18\ngini = 0.36\nsamples = 12.8%\nvalue = [0.23, 0.77]\nclass = alta qualidade'),
#  Text(18.80192775974026, 125.44615384615385, 'residual sugar <= 0.66\ngini = 0.42\nsamples = 6.9%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(8.967857142857143, 108.72, 'fixed acidity <= -0.92\ngini = 0.49\nsamples = 2.9%\nvalue = [0.42, 0.58]\nclass = alta qualidade'),
#  Text(5.978571428571429, 91.99384615384615, 'citric acid <= -0.55\ngini = 0.46\nsamples = 0.6%\nvalue = [0.63, 0.37]\nclass = baixa qualidade'),
#  Text(5.4350649350649345, 75.2676923076923, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(6.522077922077922, 75.2676923076923, 'residual sugar <= 0.43\ngini = 0.5\nsamples = 0.4%\nvalue = [0.48, 0.52]\nclass = alta qualidade'),
#  Text(5.978571428571429, 58.541538461538465, 'sulphates <= -0.64\ngini = 0.48\nsamples = 0.3%\nvalue = [0.39, 0.61]\nclass = alta qualidade'),
#  Text(5.4350649350649345, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(6.522077922077922, 41.81538461538463, 'fixed acidity <= -1.77\ngini = 0.5\nsamples = 0.3%\nvalue = [0.54, 0.46]\nclass = baixa qualidade'),
#  Text(5.978571428571429, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(7.065584415584415, 25.089230769230767, 'alcohol <= -0.25\ngini = 0.48\nsamples = 0.2%\nvalue = [0.4, 0.6]\nclass = alta qualidade'),
#  Text(6.522077922077922, 8.363076923076932, 'gini = 0.38\nsamples = 0.2%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(7.609090909090909, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(7.065584415584415, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(11.957142857142857, 91.99384615384615, 'fixed acidity <= 0.13\ngini = 0.46\nsamples = 2.3%\nvalue = [0.36, 0.64]\nclass = alta qualidade'),
#  Text(10.326623376623376, 75.2676923076923, 'free sulfur dioxide <= 1.5\ngini = 0.36\nsamples = 1.2%\nvalue = [0.23, 0.77]\nclass = alta qualidade'),
#  Text(9.783116883116882, 58.541538461538465, 'sulphates <= -2.21\ngini = 0.31\nsamples = 1.1%\nvalue = [0.19, 0.81]\nclass = alta qualidade'),
#  Text(9.23961038961039, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(10.326623376623376, 41.81538461538463, 'free sulfur dioxide <= -0.25\ngini = 0.27\nsamples = 1.1%\nvalue = [0.16, 0.84]\nclass = alta qualidade'),
#  Text(9.23961038961039, 25.089230769230767, 'total sulfur dioxide <= 0.05\ngini = 0.49\nsamples = 0.2%\nvalue = [0.44, 0.56]\nclass = alta qualidade'),
#  Text(8.696103896103896, 8.363076923076932, 'gini = 0.32\nsamples = 0.1%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(9.783116883116882, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(11.413636363636364, 25.089230769230767, 'residual sugar <= 0.35\ngini = 0.19\nsamples = 0.9%\nvalue = [0.11, 0.89]\nclass = alta qualidade'),
#  Text(10.870129870129869, 8.363076923076932, 'gini = 0.06\nsamples = 0.6%\nvalue = [0.03, 0.97]\nclass = alta qualidade'),
#  Text(11.957142857142857, 8.363076923076932, 'gini = 0.38\nsamples = 0.3%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(10.870129870129869, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(13.587662337662337, 75.2676923076923, 'alcohol <= -1.25\ngini = 0.5\nsamples = 1.2%\nvalue = [0.49, 0.51]\nclass = alta qualidade'),
#  Text(13.044155844155844, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(14.13116883116883, 58.541538461538465, 'total sulfur dioxide <= -0.71\ngini = 0.5\nsamples = 1.1%\nvalue = [0.46, 0.54]\nclass = alta qualidade'),
#  Text(13.587662337662337, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(14.674675324675324, 41.81538461538463, 'residual sugar <= -0.99\ngini = 0.49\nsamples = 1.0%\nvalue = [0.42, 0.58]\nclass = alta qualidade'),
#  Text(13.587662337662337, 25.089230769230767, 'total sulfur dioxide <= -0.28\ngini = 0.39\nsamples = 0.6%\nvalue = [0.27, 0.73]\nclass = alta qualidade'),
#  Text(13.044155844155844, 8.363076923076932, 'gini = 0.32\nsamples = 0.1%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(14.13116883116883, 8.363076923076932, 'gini = 0.27\nsamples = 0.5%\nvalue = [0.16, 0.84]\nclass = alta qualidade'),
#  Text(15.761688311688312, 25.089230769230767, 'total sulfur dioxide <= -0.24\ngini = 0.48\nsamples = 0.4%\nvalue = [0.61, 0.39]\nclass = baixa qualidade'),
#  Text(15.218181818181819, 8.363076923076932, 'gini = 0.24\nsamples = 0.1%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(16.305194805194805, 8.363076923076932, 'gini = 0.3\nsamples = 0.3%\nvalue = [0.81, 0.19]\nclass = baixa qualidade'),
#  Text(28.635998376623377, 108.72, 'citric acid <= 2.24\ngini = 0.34\nsamples = 4.0%\nvalue = [0.22, 0.78]\nclass = alta qualidade'),
#  Text(25.476866883116884, 91.99384615384615, 'pH <= -0.03\ngini = 0.32\nsamples = 3.9%\nvalue = [0.2, 0.8]\nclass = alta qualidade'),
#  Text(20.789123376623376, 75.2676923076923, 'citric acid <= 0.69\ngini = 0.21\nsamples = 2.6%\nvalue = [0.12, 0.88]\nclass = alta qualidade'),
#  Text(18.47922077922078, 58.541538461538465, 'pH <= -2.46\ngini = 0.1\nsamples = 2.2%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(17.935714285714287, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(19.022727272727273, 41.81538461538463, 'chlorides <= -0.39\ngini = 0.08\nsamples = 2.2%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(17.935714285714287, 25.089230769230767, 'citric acid <= 0.36\ngini = 0.24\nsamples = 0.5%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(17.392207792207792, 8.363076923076932, 'gini = 0.15\nsamples = 0.5%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(18.47922077922078, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(20.10974025974026, 25.089230769230767, 'free sulfur dioxide <= 2.16\ngini = 0.02\nsamples = 1.7%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(19.566233766233765, 8.363076923076932, 'gini = 0.0\nsamples = 1.5%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(20.65324675324675, 8.363076923076932, 'gini = 0.28\nsamples = 0.1%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(23.099025974025974, 58.541538461538465, 'pH <= -1.78\ngini = 0.5\nsamples = 0.4%\nvalue = [0.45, 0.55]\nclass = alta qualidade'),
#  Text(21.740259740259738, 41.81538461538463, 'chlorides <= 1.27\ngini = 0.22\nsamples = 0.2%\nvalue = [0.88, 0.12]\nclass = baixa qualidade'),
#  Text(21.196753246753246, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(22.283766233766233, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(24.457792207792206, 41.81538461538463, 'pH <= -0.42\ngini = 0.34\nsamples = 0.3%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(23.37077922077922, 25.089230769230767, 'residual sugar <= 1.62\ngini = 0.17\nsamples = 0.2%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(22.827272727272728, 8.363076923076932, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(23.914285714285715, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(25.544805194805193, 25.089230769230767, 'citric acid <= 0.88\ngini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(25.0012987012987, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(26.088311688311688, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(30.164610389610388, 75.2676923076923, 'total sulfur dioxide <= 0.18\ngini = 0.46\nsamples = 1.3%\nvalue = [0.36, 0.64]\nclass = alta qualidade'),
#  Text(29.621103896103897, 58.541538461538465, 'gini = 0.0\nsamples = 0.3%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(30.708116883116883, 58.541538461538465, 'citric acid <= 0.46\ngini = 0.5\nsamples = 0.9%\nvalue = [0.49, 0.51]\nclass = alta qualidade'),
#  Text(28.805844155844156, 41.81538461538463, 'total sulfur dioxide <= 0.43\ngini = 0.47\nsamples = 0.7%\nvalue = [0.62, 0.38]\nclass = baixa qualidade'),
#  Text(27.71883116883117, 25.089230769230767, 'alcohol <= -0.41\ngini = 0.21\nsamples = 0.3%\nvalue = [0.88, 0.12]\nclass = baixa qualidade'),
#  Text(27.175324675324674, 8.363076923076932, 'gini = 0.0\nsamples = 0.3%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(28.26233766233766, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(29.892857142857142, 25.089230769230767, 'citric acid <= -0.26\ngini = 0.48\nsamples = 0.4%\nvalue = [0.4, 0.6]\nclass = alta qualidade'),
#  Text(29.349350649350647, 8.363076923076932, 'gini = 0.28\nsamples = 0.1%\nvalue = [0.83, 0.17]\nclass = baixa qualidade'),
#  Text(30.436363636363637, 8.363076923076932, 'gini = 0.34\nsamples = 0.3%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(32.61038961038961, 41.81538461538463, 'fixed acidity <= -0.57\ngini = 0.15\nsamples = 0.2%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(32.06688311688312, 25.089230769230767, 'residual sugar <= 0.75\ngini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(31.523376623376624, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(32.61038961038961, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(33.1538961038961, 25.089230769230767, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(31.79512987012987, 91.99384615384615, 'volatile acidity <= -0.85\ngini = 0.24\nsamples = 0.1%\nvalue = [0.86, 0.14]\nclass = baixa qualidade'),
#  Text(31.251623376623375, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(32.33863636363636, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(48.96653814935065, 125.44615384615385, 'citric acid <= 2.49\ngini = 0.25\nsamples = 5.8%\nvalue = [0.15, 0.85]\nclass = alta qualidade'),
#  Text(46.707589285714285, 108.72, 'total sulfur dioxide <= 2.24\ngini = 0.24\nsamples = 5.7%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(43.82021103896104, 91.99384615384615, 'volatile acidity <= -0.94\ngini = 0.23\nsamples = 5.6%\nvalue = [0.13, 0.87]\nclass = alta qualidade'),
#  Text(39.67597402597403, 75.2676923076923, 'fixed acidity <= 1.44\ngini = 0.16\nsamples = 4.1%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(37.50194805194805, 58.541538461538465, 'citric acid <= -0.55\ngini = 0.14\nsamples = 4.0%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(35.327922077922075, 41.81538461538463, 'free sulfur dioxide <= 0.77\ngini = 0.39\nsamples = 0.3%\nvalue = [0.27, 0.73]\nclass = alta qualidade'),
#  Text(34.24090909090909, 25.089230769230767, 'free sulfur dioxide <= -0.67\ngini = 0.17\nsamples = 0.2%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(33.69740259740259, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(34.784415584415584, 8.363076923076932, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(36.414935064935065, 25.089230769230767, 'residual sugar <= 0.36\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(35.871428571428574, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(36.95844155844156, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(39.67597402597403, 41.81538461538463, 'residual sugar <= -1.53\ngini = 0.11\nsamples = 3.7%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(38.58896103896104, 25.089230769230767, 'citric acid <= 0.15\ngini = 0.48\nsamples = 0.1%\nvalue = [0.4, 0.6]\nclass = alta qualidade'),
#  Text(38.04545454545455, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(39.13246753246753, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(40.76298701298701, 25.089230769230767, 'total sulfur dioxide <= -0.17\ngini = 0.09\nsamples = 3.6%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(40.21948051948052, 8.363076923076932, 'gini = 0.24\nsamples = 0.5%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(41.3064935064935, 8.363076923076932, 'gini = 0.06\nsamples = 3.0%\nvalue = [0.03, 0.97]\nclass = alta qualidade'),
#  Text(41.85, 58.541538461538465, 'volatile acidity <= -1.49\ngini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(41.3064935064935, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(42.39350649350649, 41.81538461538463, 'pH <= -0.97\ngini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(41.85, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(42.937012987012984, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(47.964448051948054, 75.2676923076923, 'fixed acidity <= 0.04\ngini = 0.37\nsamples = 1.5%\nvalue = [0.24, 0.76]\nclass = alta qualidade'),
#  Text(45.654545454545456, 58.541538461538465, 'fixed acidity <= -1.12\ngini = 0.23\nsamples = 0.9%\nvalue = [0.13, 0.87]\nclass = alta qualidade'),
#  Text(44.567532467532466, 41.81538461538463, 'citric acid <= -0.33\ngini = 0.5\nsamples = 0.1%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(44.024025974025975, 25.089230769230767, 'citric acid <= -0.74\ngini = 0.38\nsamples = 0.1%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(43.480519480519476, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(44.567532467532466, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(45.11103896103896, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(46.74155844155844, 41.81538461538463, 'chlorides <= 0.83\ngini = 0.14\nsamples = 0.8%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(46.19805194805195, 25.089230769230767, 'pH <= -1.11\ngini = 0.1\nsamples = 0.8%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(45.654545454545456, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(46.74155844155844, 8.363076923076932, 'gini = 0.0\nsamples = 0.6%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(47.28506493506493, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(50.27435064935065, 58.541538461538465, 'fixed acidity <= 0.22\ngini = 0.48\nsamples = 0.6%\nvalue = [0.39, 0.61]\nclass = alta qualidade'),
#  Text(48.91558441558441, 41.81538461538463, 'total sulfur dioxide <= 1.41\ngini = 0.32\nsamples = 0.2%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(48.37207792207792, 25.089230769230767, 'residual sugar <= -0.5\ngini = 0.2\nsamples = 0.2%\nvalue = [0.89, 0.11]\nclass = baixa qualidade'),
#  Text(47.82857142857143, 8.363076923076932, 'gini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(48.91558441558441, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(49.45909090909091, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(51.633116883116884, 41.81538461538463, 'residual sugar <= 1.49\ngini = 0.34\nsamples = 0.4%\nvalue = [0.22, 0.78]\nclass = alta qualidade'),
#  Text(50.546103896103894, 25.089230769230767, 'free sulfur dioxide <= 1.37\ngini = 0.11\nsamples = 0.3%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(50.0025974025974, 8.363076923076932, 'gini = 0.0\nsamples = 0.3%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(51.089610389610385, 8.363076923076932, 'gini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(52.72012987012987, 25.089230769230767, 'chlorides <= 0.15\ngini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(52.176623376623375, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(53.263636363636365, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(49.59496753246753, 91.99384615384615, 'alcohol <= -0.07\ngini = 0.48\nsamples = 0.1%\nvalue = [0.6, 0.4]\nclass = baixa qualidade'),
#  Text(49.05146103896104, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(50.13847402597403, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(51.22548701298701, 108.72, 'residual sugar <= 1.42\ngini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(50.68198051948052, 91.99384615384615, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(51.76899350649351, 91.99384615384615, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(86.21371753246753, 158.89846153846153, 'alcohol <= -0.45\ngini = 0.5\nsamples = 13.4%\nvalue = [0.46, 0.54]\nclass = alta qualidade'),
#  Text(69.36501623376623, 142.1723076923077, 'pH <= -0.9\ngini = 0.5\nsamples = 9.0%\nvalue = [0.52, 0.48]\nclass = baixa qualidade'),
#  Text(56.660551948051946, 125.44615384615385, 'alcohol <= -1.65\ngini = 0.47\nsamples = 2.3%\nvalue = [0.37, 0.63]\nclass = alta qualidade'),
#  Text(53.80714285714286, 108.72, 'citric acid <= -0.09\ngini = 0.38\nsamples = 0.4%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(53.263636363636365, 91.99384615384615, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(54.35064935064935, 91.99384615384615, 'free sulfur dioxide <= 1.5\ngini = 0.21\nsamples = 0.3%\nvalue = [0.88, 0.12]\nclass = baixa qualidade'),
#  Text(53.80714285714286, 75.2676923076923, 'citric acid <= 0.46\ngini = 0.12\nsamples = 0.3%\nvalue = [0.94, 0.06]\nclass = baixa qualidade'),
#  Text(53.263636363636365, 58.541538461538465, 'chlorides <= -0.21\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(52.72012987012987, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(53.80714285714286, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(54.35064935064935, 58.541538461538465, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(54.89415584415584, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(59.513961038961035, 108.72, 'free sulfur dioxide <= -0.22\ngini = 0.42\nsamples = 2.0%\nvalue = [0.29, 0.71]\nclass = alta qualidade'),
#  Text(56.52467532467532, 91.99384615384615, 'citric acid <= -0.3\ngini = 0.43\nsamples = 0.3%\nvalue = [0.69, 0.31]\nclass = baixa qualidade'),
#  Text(55.98116883116883, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(57.06818181818182, 75.2676923076923, 'residual sugar <= -0.13\ngini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(56.52467532467532, 58.541538461538465, 'fixed acidity <= 1.05\ngini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(55.98116883116883, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(57.06818181818182, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(57.61168831168831, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(62.50324675324675, 91.99384615384615, 'total sulfur dioxide <= 1.45\ngini = 0.36\nsamples = 1.7%\nvalue = [0.24, 0.76]\nclass = alta qualidade'),
#  Text(60.329220779220776, 75.2676923076923, 'free sulfur dioxide <= 0.93\ngini = 0.29\nsamples = 1.4%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(58.698701298701295, 58.541538461538465, 'residual sugar <= -1.42\ngini = 0.11\nsamples = 0.9%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(58.1551948051948, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(59.24220779220779, 41.81538461538463, 'residual sugar <= 1.57\ngini = 0.08\nsamples = 0.9%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(58.698701298701295, 25.089230769230767, 'gini = 0.0\nsamples = 0.8%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(59.785714285714285, 25.089230769230767, 'free sulfur dioxide <= 0.71\ngini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(59.24220779220779, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(60.329220779220776, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(61.95974025974026, 58.541538461538465, 'sulphates <= -0.54\ngini = 0.47\nsamples = 0.5%\nvalue = [0.38, 0.62]\nclass = alta qualidade'),
#  Text(61.416233766233766, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(62.50324675324675, 41.81538461538463, 'chlorides <= 1.06\ngini = 0.27\nsamples = 0.4%\nvalue = [0.16, 0.84]\nclass = alta qualidade'),
#  Text(61.95974025974026, 25.089230769230767, 'pH <= -0.97\ngini = 0.2\nsamples = 0.3%\nvalue = [0.11, 0.89]\nclass = alta qualidade'),
#  Text(61.416233766233766, 8.363076923076932, 'gini = 0.11\nsamples = 0.3%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(62.50324675324675, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(63.04675324675325, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(64.67727272727272, 75.2676923076923, 'pH <= -1.86\ngini = 0.49\nsamples = 0.3%\nvalue = [0.57, 0.43]\nclass = baixa qualidade'),
#  Text(64.13376623376624, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(65.22077922077922, 58.541538461538465, 'alcohol <= -1.13\ngini = 0.44\nsamples = 0.2%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(64.67727272727272, 41.81538461538463, 'chlorides <= -0.15\ngini = 0.5\nsamples = 0.2%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(64.13376623376624, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(65.22077922077922, 25.089230769230767, 'citric acid <= 1.1\ngini = 0.32\nsamples = 0.1%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(64.67727272727272, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(65.76428571428572, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(65.76428571428572, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(82.06948051948052, 125.44615384615385, 'chlorides <= -0.21\ngini = 0.49\nsamples = 6.7%\nvalue = [0.58, 0.42]\nclass = baixa qualidade'),
#  Text(74.90198863636364, 108.72, 'pH <= 0.41\ngini = 0.5\nsamples = 2.4%\nvalue = [0.46, 0.54]\nclass = alta qualidade'),
#  Text(69.90852272727273, 91.99384615384615, 'total sulfur dioxide <= 0.31\ngini = 0.5\nsamples = 1.8%\nvalue = [0.53, 0.47]\nclass = baixa qualidade'),
#  Text(67.93831168831169, 75.2676923076923, 'residual sugar <= 0.34\ngini = 0.34\nsamples = 0.3%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(67.39480519480519, 58.541538461538465, 'total sulfur dioxide <= 0.07\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(66.8512987012987, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(67.93831168831169, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(68.48181818181818, 58.541538461538465, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(71.87873376623376, 75.2676923076923, 'sulphates <= -0.36\ngini = 0.49\nsamples = 1.5%\nvalue = [0.58, 0.42]\nclass = baixa qualidade'),
#  Text(69.56883116883117, 58.541538461538465, 'fixed acidity <= -0.57\ngini = 0.29\nsamples = 0.5%\nvalue = [0.82, 0.18]\nclass = baixa qualidade'),
#  Text(69.02532467532467, 41.81538461538463, 'pH <= -0.52\ngini = 0.5\nsamples = 0.2%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(68.48181818181818, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(69.56883116883117, 25.089230769230767, 'fixed acidity <= -0.8\ngini = 0.28\nsamples = 0.1%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(69.02532467532467, 8.363076923076932, 'gini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(70.11233766233767, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(70.11233766233767, 41.81538461538463, 'gini = 0.0\nsamples = 0.3%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(74.18863636363636, 58.541538461538465, 'pH <= -0.03\ngini = 0.5\nsamples = 1.0%\nvalue = [0.45, 0.55]\nclass = alta qualidade'),
#  Text(72.82987012987013, 41.81538461538463, 'residual sugar <= 0.95\ngini = 0.42\nsamples = 0.6%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(71.74285714285715, 25.089230769230767, 'residual sugar <= 0.8\ngini = 0.47\nsamples = 0.3%\nvalue = [0.62, 0.38]\nclass = baixa qualidade'),
#  Text(71.19935064935065, 8.363076923076932, 'gini = 0.47\nsamples = 0.2%\nvalue = [0.38, 0.62]\nclass = alta qualidade'),
#  Text(72.28636363636363, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(73.91688311688311, 25.089230769230767, 'fixed acidity <= -0.68\ngini = 0.18\nsamples = 0.4%\nvalue = [0.1, 0.9]\nclass = alta qualidade'),
#  Text(73.37337662337661, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(74.46038961038961, 8.363076923076932, 'gini = 0.1\nsamples = 0.4%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(75.5474025974026, 41.81538461538463, 'citric acid <= 0.49\ngini = 0.4\nsamples = 0.3%\nvalue = [0.72, 0.28]\nclass = baixa qualidade'),
#  Text(75.0038961038961, 25.089230769230767, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(76.0909090909091, 25.089230769230767, 'sulphates <= 0.3\ngini = 0.47\nsamples = 0.2%\nvalue = [0.38, 0.62]\nclass = alta qualidade'),
#  Text(75.5474025974026, 8.363076923076932, 'gini = 0.28\nsamples = 0.1%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(76.63441558441558, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(79.89545454545454, 91.99384615384615, 'residual sugar <= 1.6\ngini = 0.4\nsamples = 0.6%\nvalue = [0.27, 0.73]\nclass = alta qualidade'),
#  Text(79.35194805194806, 75.2676923076923, 'pH <= 1.75\ngini = 0.35\nsamples = 0.6%\nvalue = [0.23, 0.77]\nclass = alta qualidade'),
#  Text(78.80844155844156, 58.541538461538465, 'chlorides <= -0.96\ngini = 0.29\nsamples = 0.6%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(77.72142857142858, 41.81538461538463, 'citric acid <= -0.59\ngini = 0.5\nsamples = 0.1%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(77.17792207792208, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(78.26493506493506, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(79.89545454545454, 41.81538461538463, 'fixed acidity <= -1.32\ngini = 0.16\nsamples = 0.4%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(79.35194805194806, 25.089230769230767, 'citric acid <= -0.41\ngini = 0.5\nsamples = 0.1%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(78.80844155844156, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(79.89545454545454, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(80.43896103896104, 25.089230769230767, 'gini = 0.0\nsamples = 0.4%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(79.89545454545454, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(80.43896103896104, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(89.2369724025974, 108.72, 'sulphates <= 1.21\ngini = 0.46\nsamples = 4.3%\nvalue = [0.64, 0.36]\nclass = baixa qualidade'),
#  Text(85.53433441558441, 91.99384615384615, 'citric acid <= -0.55\ngini = 0.44\nsamples = 4.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(82.06948051948052, 75.2676923076923, 'chlorides <= -0.15\ngini = 0.13\nsamples = 0.5%\nvalue = [0.93, 0.07]\nclass = baixa qualidade'),
#  Text(81.52597402597402, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(82.612987012987, 58.541538461538465, 'alcohol <= -1.79\ngini = 0.07\nsamples = 0.5%\nvalue = [0.96, 0.04]\nclass = baixa qualidade'),
#  Text(82.06948051948052, 41.81538461538463, 'free sulfur dioxide <= 0.8\ngini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(81.52597402597402, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(82.612987012987, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(83.1564935064935, 41.81538461538463, 'gini = 0.0\nsamples = 0.5%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(88.99918831168831, 75.2676923076923, 'fixed acidity <= 0.22\ngini = 0.46\nsamples = 3.5%\nvalue = [0.63, 0.37]\nclass = baixa qualidade'),
#  Text(86.14577922077922, 58.541538461538465, 'pH <= -0.69\ngini = 0.49\nsamples = 2.6%\nvalue = [0.56, 0.44]\nclass = baixa qualidade'),
#  Text(84.24350649350649, 41.81538461538463, 'free sulfur dioxide <= -0.11\ngini = 0.33\nsamples = 0.5%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(83.7, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(84.78701298701299, 25.089230769230767, 'sulphates <= 0.7\ngini = 0.17\nsamples = 0.4%\nvalue = [0.1, 0.9]\nclass = alta qualidade'),
#  Text(84.24350649350649, 8.363076923076932, 'gini = 0.09\nsamples = 0.4%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(85.33051948051948, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(88.04805194805195, 41.81538461538463, 'citric acid <= 0.56\ngini = 0.47\nsamples = 2.1%\nvalue = [0.63, 0.37]\nclass = baixa qualidade'),
#  Text(86.96103896103895, 25.089230769230767, 'citric acid <= 0.36\ngini = 0.5\nsamples = 1.4%\nvalue = [0.54, 0.46]\nclass = baixa qualidade'),
#  Text(86.41753246753247, 8.363076923076932, 'gini = 0.48\nsamples = 1.3%\nvalue = [0.59, 0.41]\nclass = baixa qualidade'),
#  Text(87.50454545454545, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(89.13506493506493, 25.089230769230767, 'free sulfur dioxide <= 1.14\ngini = 0.33\nsamples = 0.8%\nvalue = [0.79, 0.21]\nclass = baixa qualidade'),
#  Text(88.59155844155843, 8.363076923076932, 'gini = 0.09\nsamples = 0.4%\nvalue = [0.95, 0.05]\nclass = baixa qualidade'),
#  Text(89.67857142857143, 8.363076923076932, 'gini = 0.47\nsamples = 0.4%\nvalue = [0.63, 0.37]\nclass = baixa qualidade'),
#  Text(91.8525974025974, 58.541538461538465, 'total sulfur dioxide <= -1.73\ngini = 0.25\nsamples = 0.9%\nvalue = [0.85, 0.15]\nclass = baixa qualidade'),
#  Text(90.76558441558441, 41.81538461538463, 'residual sugar <= -0.39\ngini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(90.22207792207791, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(91.30909090909091, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(92.9396103896104, 41.81538461538463, 'citric acid <= -0.41\ngini = 0.2\nsamples = 0.9%\nvalue = [0.89, 0.11]\nclass = baixa qualidade'),
#  Text(92.3961038961039, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(93.48311688311688, 25.089230769230767, 'residual sugar <= 1.01\ngini = 0.17\nsamples = 0.8%\nvalue = [0.91, 0.09]\nclass = baixa qualidade'),
#  Text(92.9396103896104, 8.363076923076932, 'gini = 0.32\nsamples = 0.4%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(94.02662337662338, 8.363076923076932, 'gini = 0.0\nsamples = 0.5%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(92.9396103896104, 91.99384615384615, 'alcohol <= -0.67\ngini = 0.17\nsamples = 0.2%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(92.3961038961039, 75.2676923076923, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(93.48311688311688, 75.2676923076923, 'alcohol <= -0.56\ngini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(92.9396103896104, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(94.02662337662338, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(103.06241883116883, 142.1723076923077, 'free sulfur dioxide <= -0.19\ngini = 0.44\nsamples = 4.4%\nvalue = [0.32, 0.68]\nclass = alta qualidade'),
#  Text(96.74415584415584, 125.44615384615385, 'citric acid <= -0.37\ngini = 0.5\nsamples = 1.3%\nvalue = [0.52, 0.48]\nclass = baixa qualidade'),
#  Text(95.65714285714286, 108.72, 'residual sugar <= -1.14\ngini = 0.15\nsamples = 0.2%\nvalue = [0.92, 0.08]\nclass = baixa qualidade'),
#  Text(95.11363636363636, 91.99384615384615, 'free sulfur dioxide <= -1.02\ngini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(94.57012987012986, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(95.65714285714286, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(96.20064935064934, 91.99384615384615, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(97.83116883116882, 108.72, 'citric acid <= -0.12\ngini = 0.49\nsamples = 1.0%\nvalue = [0.43, 0.57]\nclass = alta qualidade'),
#  Text(97.28766233766234, 91.99384615384615, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(98.37467532467532, 91.99384615384615, 'total sulfur dioxide <= -1.67\ngini = 0.5\nsamples = 0.9%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(97.83116883116882, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(98.91818181818182, 75.2676923076923, 'free sulfur dioxide <= -0.99\ngini = 0.49\nsamples = 0.8%\nvalue = [0.56, 0.44]\nclass = baixa qualidade'),
#  Text(97.83116883116882, 58.541538461538465, 'citric acid <= 0.15\ngini = 0.15\nsamples = 0.2%\nvalue = [0.92, 0.08]\nclass = baixa qualidade'),
#  Text(97.28766233766234, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(98.37467532467532, 41.81538461538463, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(100.0051948051948, 58.541538461538465, 'pH <= 0.47\ngini = 0.49\nsamples = 0.6%\nvalue = [0.41, 0.59]\nclass = alta qualidade'),
#  Text(99.4616883116883, 41.81538461538463, 'chlorides <= 0.42\ngini = 0.5\nsamples = 0.4%\nvalue = [0.52, 0.48]\nclass = baixa qualidade'),
#  Text(98.91818181818182, 25.089230769230767, 'sulphates <= 1.16\ngini = 0.49\nsamples = 0.4%\nvalue = [0.42, 0.58]\nclass = alta qualidade'),
#  Text(98.37467532467532, 8.363076923076932, 'gini = 0.46\nsamples = 0.3%\nvalue = [0.35, 0.65]\nclass = alta qualidade'),
#  Text(99.4616883116883, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(100.0051948051948, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(100.5487012987013, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(109.38068181818181, 125.44615384615385, 'total sulfur dioxide <= 1.35\ngini = 0.37\nsamples = 3.1%\nvalue = [0.24, 0.76]\nclass = alta qualidade'),
#  Text(106.79902597402597, 108.72, 'pH <= 0.47\ngini = 0.33\nsamples = 2.8%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(104.35324675324675, 91.99384615384615, 'pH <= -0.22\ngini = 0.38\nsamples = 1.9%\nvalue = [0.26, 0.74]\nclass = alta qualidade'),
#  Text(102.72272727272727, 75.2676923076923, 'citric acid <= -0.92\ngini = 0.29\nsamples = 1.1%\nvalue = [0.18, 0.82]\nclass = alta qualidade'),
#  Text(102.17922077922077, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(103.26623376623377, 58.541538461538465, 'free sulfur dioxide <= 0.11\ngini = 0.25\nsamples = 1.1%\nvalue = [0.15, 0.85]\nclass = alta qualidade'),
#  Text(101.63571428571429, 41.81538461538463, 'fixed acidity <= 0.01\ngini = 0.5\nsamples = 0.2%\nvalue = [0.45, 0.55]\nclass = alta qualidade'),
#  Text(101.09220779220779, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(102.17922077922077, 25.089230769230767, 'total sulfur dioxide <= 0.59\ngini = 0.28\nsamples = 0.1%\nvalue = [0.83, 0.17]\nclass = baixa qualidade'),
#  Text(101.63571428571429, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(102.72272727272727, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(104.89675324675325, 41.81538461538463, 'pH <= -0.93\ngini = 0.13\nsamples = 0.8%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(104.35324675324675, 25.089230769230767, 'pH <= -1.11\ngini = 0.34\nsamples = 0.3%\nvalue = [0.21, 0.79]\nclass = alta qualidade'),
#  Text(103.80974025974025, 8.363076923076932, 'gini = 0.15\nsamples = 0.2%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(104.89675324675325, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(105.44025974025973, 25.089230769230767, 'gini = 0.0\nsamples = 0.6%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(105.98376623376623, 75.2676923076923, 'fixed acidity <= -1.25\ngini = 0.46\nsamples = 0.8%\nvalue = [0.36, 0.64]\nclass = alta qualidade'),
#  Text(105.44025974025973, 58.541538461538465, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(106.52727272727273, 58.541538461538465, 'total sulfur dioxide <= -0.16\ngini = 0.49\nsamples = 0.7%\nvalue = [0.44, 0.56]\nclass = alta qualidade'),
#  Text(105.98376623376623, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(107.07077922077922, 41.81538461538463, 'sulphates <= 0.94\ngini = 0.5\nsamples = 0.6%\nvalue = [0.53, 0.47]\nclass = baixa qualidade'),
#  Text(106.52727272727273, 25.089230769230767, 'alcohol <= 0.11\ngini = 0.5\nsamples = 0.5%\nvalue = [0.46, 0.54]\nclass = alta qualidade'),
#  Text(105.98376623376623, 8.363076923076932, 'gini = 0.45\nsamples = 0.4%\nvalue = [0.35, 0.65]\nclass = alta qualidade'),
#  Text(107.07077922077922, 8.363076923076932, 'gini = 0.28\nsamples = 0.1%\nvalue = [0.83, 0.17]\nclass = baixa qualidade'),
#  Text(107.61428571428571, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(109.2448051948052, 91.99384615384615, 'chlorides <= -1.16\ngini = 0.16\nsamples = 0.9%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(108.7012987012987, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(109.78831168831168, 75.2676923076923, 'free sulfur dioxide <= 1.16\ngini = 0.13\nsamples = 0.8%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(108.7012987012987, 58.541538461538465, 'sulphates <= 1.03\ngini = 0.05\nsamples = 0.8%\nvalue = [0.02, 0.98]\nclass = alta qualidade'),
#  Text(108.1577922077922, 41.81538461538463, 'gini = 0.0\nsamples = 0.7%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(109.2448051948052, 41.81538461538463, 'total sulfur dioxide <= 0.43\ngini = 0.38\nsamples = 0.1%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(108.7012987012987, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(109.78831168831168, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(110.87532467532468, 58.541538461538465, 'residual sugar <= 0.86\ngini = 0.5\nsamples = 0.1%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(110.33181818181818, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(111.41883116883116, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(111.96233766233766, 108.72, 'chlorides <= -0.15\ngini = 0.49\nsamples = 0.3%\nvalue = [0.56, 0.44]\nclass = baixa qualidade'),
#  Text(111.41883116883116, 91.99384615384615, 'total sulfur dioxide <= 1.45\ngini = 0.42\nsamples = 0.2%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(110.87532467532468, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(111.96233766233766, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(112.50584415584416, 91.99384615384615, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(185.43125253652596, 175.62461538461537, 'alcohol <= -0.45\ngini = 0.44\nsamples = 30.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(162.89484070616882, 158.89846153846153, 'fixed acidity <= 1.87\ngini = 0.4\nsamples = 21.0%\nvalue = [0.73, 0.27]\nclass = baixa qualidade'),
#  Text(152.13935673701297, 142.1723076923077, 'volatile acidity <= 1.47\ngini = 0.39\nsamples = 20.0%\nvalue = [0.74, 0.26]\nclass = baixa qualidade'),
#  Text(138.98480113636364, 125.44615384615385, 'sulphates <= 0.51\ngini = 0.41\nsamples = 15.3%\nvalue = [0.71, 0.29]\nclass = baixa qualidade'),
#  Text(124.29314123376624, 108.72, 'citric acid <= -0.48\ngini = 0.38\nsamples = 10.7%\nvalue = [0.74, 0.26]\nclass = baixa qualidade'),
#  Text(118.0767857142857, 91.99384615384615, 'alcohol <= -0.56\ngini = 0.3\nsamples = 4.2%\nvalue = [0.81, 0.19]\nclass = baixa qualidade'),
#  Text(115.49512987012987, 75.2676923076923, 'sulphates <= -0.54\ngini = 0.27\nsamples = 3.8%\nvalue = [0.84, 0.16]\nclass = baixa qualidade'),
#  Text(113.59285714285714, 58.541538461538465, 'free sulfur dioxide <= 1.37\ngini = 0.41\nsamples = 1.2%\nvalue = [0.71, 0.29]\nclass = baixa qualidade'),
#  Text(112.50584415584416, 41.81538461538463, 'total sulfur dioxide <= 0.25\ngini = 0.32\nsamples = 0.9%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(111.96233766233766, 25.089230769230767, 'chlorides <= -0.36\ngini = 0.42\nsamples = 0.7%\nvalue = [0.71, 0.29]\nclass = baixa qualidade'),
#  Text(111.41883116883116, 8.363076923076932, 'gini = 0.0\nsamples = 0.2%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(112.50584415584416, 8.363076923076932, 'gini = 0.49\nsamples = 0.5%\nvalue = [0.58, 0.42]\nclass = baixa qualidade'),
#  Text(113.04935064935064, 25.089230769230767, 'gini = 0.0\nsamples = 0.3%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(114.67987012987012, 41.81538461538463, 'free sulfur dioxide <= 1.76\ngini = 0.47\nsamples = 0.3%\nvalue = [0.38, 0.62]\nclass = alta qualidade'),
#  Text(114.13636363636364, 25.089230769230767, 'residual sugar <= 0.53\ngini = 0.32\nsamples = 0.2%\nvalue = [0.2, 0.8]\nclass = alta qualidade'),
#  Text(113.59285714285714, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(114.67987012987012, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(115.22337662337662, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(117.39740259740259, 58.541538461538465, 'residual sugar <= 1.66\ngini = 0.18\nsamples = 2.7%\nvalue = [0.9, 0.1]\nclass = baixa qualidade'),
#  Text(116.8538961038961, 41.81538461538463, 'volatile acidity <= 1.46\ngini = 0.17\nsamples = 2.6%\nvalue = [0.91, 0.09]\nclass = baixa qualidade'),
#  Text(116.3103896103896, 25.089230769230767, 'residual sugar <= -1.53\ngini = 0.16\nsamples = 2.6%\nvalue = [0.91, 0.09]\nclass = baixa qualidade'),
#  Text(115.76688311688311, 8.363076923076932, 'gini = 0.5\nsamples = 0.1%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(116.8538961038961, 8.363076923076932, 'gini = 0.14\nsamples = 2.5%\nvalue = [0.92, 0.08]\nclass = baixa qualidade'),
# ...
#  Text(294.3087662337662, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(294.85227272727275, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(297.0262987012987, 58.541538461538465, 'chlorides <= 0.42\ngini = 0.26\nsamples = 0.9%\nvalue = [0.16, 0.84]\nclass = alta qualidade'),
#  Text(295.9392857142857, 41.81538461538463, 'alcohol <= 0.85\ngini = 0.32\nsamples = 0.1%\nvalue = [0.8, 0.2]\nclass = baixa qualidade'),
#  Text(295.3957792207792, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(296.4827922077922, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(298.1133116883117, 41.81538461538463, 'alcohol <= 0.59\ngini = 0.14\nsamples = 0.8%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(297.5698051948052, 25.089230769230767, 'volatile acidity <= 1.38\ngini = 0.42\nsamples = 0.2%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(297.0262987012987, 8.363076923076932, 'gini = 0.44\nsamples = 0.1%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(298.1133116883117, 8.363076923076932, 'gini = 0.24\nsamples = 0.1%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(298.65681818181815, 25.089230769230767, 'gini = 0.0\nsamples = 0.6%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(288.3981331168831, 142.1723076923077, 'sulphates <= 0.57\ngini = 0.22\nsamples = 0.2%\nvalue = [0.88, 0.12]\nclass = baixa qualidade'),
#  Text(287.8546266233766, 125.44615384615385, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(288.9416396103896, 125.44615384615385, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(321.280275974026, 175.62461538461537, 'volatile acidity <= 1.3\ngini = 0.13\nsamples = 20.2%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(310.4780844155844, 158.89846153846153, 'fixed acidity <= 2.78\ngini = 0.1\nsamples = 18.7%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(309.9345779220779, 142.1723076923077, 'free sulfur dioxide <= -1.17\ngini = 0.1\nsamples = 18.6%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(301.51022727272726, 125.44615384615385, 'chlorides <= 0.47\ngini = 0.26\nsamples = 2.3%\nvalue = [0.15, 0.85]\nclass = alta qualidade'),
#  Text(300.0155844155844, 108.72, 'alcohol <= 1.08\ngini = 0.42\nsamples = 1.1%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(298.65681818181815, 91.99384615384615, 'sulphates <= 0.57\ngini = 0.38\nsamples = 0.2%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(298.1133116883117, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(299.2003246753247, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(301.3743506493506, 91.99384615384615, 'total sulfur dioxide <= -0.83\ngini = 0.35\nsamples = 0.9%\nvalue = [0.22, 0.78]\nclass = alta qualidade'),
#  Text(300.2873376623377, 75.2676923076923, 'total sulfur dioxide <= -1.1\ngini = 0.48\nsamples = 0.4%\nvalue = [0.41, 0.59]\nclass = alta qualidade'),
#  Text(299.74383116883115, 58.541538461538465, 'residual sugar <= -0.44\ngini = 0.36\nsamples = 0.3%\nvalue = [0.24, 0.76]\nclass = alta qualidade'),
#  Text(299.2003246753247, 41.81538461538463, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(300.2873376623377, 41.81538461538463, 'residual sugar <= 0.66\ngini = 0.49\nsamples = 0.1%\nvalue = [0.57, 0.43]\nclass = baixa qualidade'),
#  Text(299.74383116883115, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(300.83084415584415, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(300.83084415584415, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(302.4613636363636, 75.2676923076923, 'pH <= -1.98\ngini = 0.14\nsamples = 0.5%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(301.91785714285714, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(303.00487012987014, 58.541538461538465, 'pH <= 0.84\ngini = 0.07\nsamples = 0.5%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(302.4613636363636, 41.81538461538463, 'gini = 0.0\nsamples = 0.4%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(303.5483766233766, 41.81538461538463, 'total sulfur dioxide <= -0.07\ngini = 0.44\nsamples = 0.1%\nvalue = [0.33, 0.67]\nclass = alta qualidade'),
#  Text(303.00487012987014, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(304.0918831168831, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(303.00487012987014, 108.72, 'citric acid <= 2.24\ngini = 0.03\nsamples = 1.2%\nvalue = [0.02, 0.98]\nclass = alta qualidade'),
#  Text(302.4613636363636, 91.99384615384615, 'gini = 0.0\nsamples = 1.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(303.5483766233766, 91.99384615384615, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(318.3589285714286, 125.44615384615385, 'residual sugar <= 1.79\ngini = 0.07\nsamples = 16.4%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(317.81542207792205, 108.72, 'alcohol <= 1.24\ngini = 0.07\nsamples = 16.3%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(309.2551948051948, 91.99384615384615, 'sulphates <= -2.35\ngini = 0.12\nsamples = 5.3%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(308.7116883116883, 75.2676923076923, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(309.7987012987013, 75.2676923076923, 'residual sugar <= -1.35\ngini = 0.12\nsamples = 5.3%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(306.8094155844156, 58.541538461538465, 'total sulfur dioxide <= 0.51\ngini = 0.3\nsamples = 0.5%\nvalue = [0.19, 0.81]\nclass = alta qualidade'),
#  Text(305.7224025974026, 41.81538461538463, 'pH <= 1.44\ngini = 0.16\nsamples = 0.4%\nvalue = [0.09, 0.91]\nclass = alta qualidade'),
#  Text(305.1788961038961, 25.089230769230767, 'citric acid <= -0.23\ngini = 0.09\nsamples = 0.4%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(304.6353896103896, 8.363076923076932, 'gini = 0.5\nsamples = 0.0%\nvalue = [0.5, 0.5]\nclass = baixa qualidade'),
#  Text(305.7224025974026, 8.363076923076932, 'gini = 0.0\nsamples = 0.4%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(306.2659090909091, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(307.89642857142854, 41.81538461538463, 'sulphates <= -1.48\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(307.3529220779221, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(308.43993506493507, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(312.787987012987, 58.541538461538465, 'alcohol <= 1.21\ngini = 0.09\nsamples = 4.7%\nvalue = [0.05, 0.95]\nclass = alta qualidade'),
#  Text(310.613961038961, 41.81538461538463, 'citric acid <= 1.74\ngini = 0.04\nsamples = 3.1%\nvalue = [0.02, 0.98]\nclass = alta qualidade'),
#  Text(309.52694805194807, 25.089230769230767, 'total sulfur dioxide <= 1.02\ngini = 0.03\nsamples = 3.0%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(308.98344155844154, 8.363076923076932, 'gini = 0.01\nsamples = 2.8%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(310.07045454545454, 8.363076923076932, 'gini = 0.15\nsamples = 0.2%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(311.700974025974, 25.089230769230767, 'residual sugar <= -0.55\ngini = 0.38\nsamples = 0.1%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(311.15746753246754, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(312.24448051948053, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(314.962012987013, 41.81538461538463, 'chlorides <= -1.64\ngini = 0.19\nsamples = 1.6%\nvalue = [0.11, 0.89]\nclass = alta qualidade'),
#  Text(313.875, 25.089230769230767, 'total sulfur dioxide <= -0.06\ngini = 0.49\nsamples = 0.1%\nvalue = [0.43, 0.57]\nclass = alta qualidade'),
#  Text(313.3314935064935, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(314.41850649350647, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(316.049025974026, 25.089230769230767, 'total sulfur dioxide <= -0.23\ngini = 0.14\nsamples = 1.5%\nvalue = [0.08, 0.92]\nclass = alta qualidade'),
#  Text(315.50551948051947, 8.363076923076932, 'gini = 0.0\nsamples = 0.6%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(316.59253246753246, 8.363076923076932, 'gini = 0.23\nsamples = 0.9%\nvalue = [0.13, 0.87]\nclass = alta qualidade'),
#  Text(326.3756493506493, 91.99384615384615, 'chlorides <= 1.2\ngini = 0.04\nsamples = 11.1%\nvalue = [0.02, 0.98]\nclass = alta qualidade'),
#  Text(323.9298701298701, 75.2676923076923, 'free sulfur dioxide <= -0.52\ngini = 0.04\nsamples = 10.9%\nvalue = [0.02, 0.98]\nclass = alta qualidade'),
#  Text(320.66883116883116, 58.541538461538465, 'citric acid <= 0.65\ngini = 0.12\nsamples = 1.8%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(319.31006493506493, 41.81538461538463, 'volatile acidity <= 1.09\ngini = 0.07\nsamples = 1.6%\nvalue = [0.04, 0.96]\nclass = alta qualidade'),
#  Text(318.22305194805193, 25.089230769230767, 'residual sugar <= -1.19\ngini = 0.03\nsamples = 1.5%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(317.67954545454546, 8.363076923076932, 'gini = 0.28\nsamples = 0.1%\nvalue = [0.17, 0.83]\nclass = alta qualidade'),
#  Text(318.76655844155846, 8.363076923076932, 'gini = 0.0\nsamples = 1.4%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(320.3970779220779, 25.089230769230767, 'pH <= -0.65\ngini = 0.38\nsamples = 0.2%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(319.8535714285714, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(320.9405844155844, 8.363076923076932, 'gini = 0.24\nsamples = 0.1%\nvalue = [0.14, 0.86]\nclass = alta qualidade'),
#  Text(322.0275974025974, 41.81538461538463, 'free sulfur dioxide <= -0.67\ngini = 0.4\nsamples = 0.2%\nvalue = [0.27, 0.73]\nclass = alta qualidade'),
#  Text(321.4840909090909, 25.089230769230767, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(322.57110389610386, 25.089230769230767, 'residual sugar <= -1.45\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(322.0275974025974, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(323.1146103896104, 8.363076923076932, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(327.1909090909091, 58.541538461538465, 'pH <= 1.21\ngini = 0.02\nsamples = 9.1%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(325.83214285714286, 41.81538461538463, 'pH <= -1.7\ngini = 0.01\nsamples = 8.5%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(324.74512987012986, 25.089230769230767, 'alcohol <= 1.32\ngini = 0.11\nsamples = 0.3%\nvalue = [0.06, 0.94]\nclass = alta qualidade'),
#  Text(324.2016233766234, 8.363076923076932, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(325.28863636363633, 8.363076923076932, 'gini = 0.0\nsamples = 0.3%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(326.91915584415585, 25.089230769230767, 'free sulfur dioxide <= 0.11\ngini = 0.01\nsamples = 8.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(326.3756493506493, 8.363076923076932, 'gini = 0.02\nsamples = 3.1%\nvalue = [0.01, 0.99]\nclass = alta qualidade'),
#  Text(327.4626623376623, 8.363076923076932, 'gini = 0.0\nsamples = 5.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(328.5496753246753, 41.81538461538463, 'pH <= 1.26\ngini = 0.12\nsamples = 0.6%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(328.00616883116885, 25.089230769230767, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(329.0931818181818, 25.089230769230767, 'total sulfur dioxide <= 0.7\ngini = 0.07\nsamples = 0.6%\nvalue = [0.03, 0.97]\nclass = alta qualidade'),
#  Text(328.5496753246753, 8.363076923076932, 'gini = 0.0\nsamples = 0.5%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(329.6366883116883, 8.363076923076932, 'gini = 0.38\nsamples = 0.1%\nvalue = [0.25, 0.75]\nclass = alta qualidade'),
#  Text(328.82142857142856, 75.2676923076923, 'alcohol <= 1.61\ngini = 0.41\nsamples = 0.1%\nvalue = [0.29, 0.71]\nclass = alta qualidade'),
#  Text(328.2779220779221, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(329.3649350649351, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(318.90243506493505, 108.72, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(311.0215909090909, 142.1723076923077, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(332.08246753246755, 158.89846153846153, 'sulphates <= -1.29\ngini = 0.36\nsamples = 1.6%\nvalue = [0.23, 0.77]\nclass = alta qualidade'),
#  Text(331.538961038961, 142.1723076923077, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(332.625974025974, 142.1723076923077, 'sulphates <= 0.7\ngini = 0.27\nsamples = 1.4%\nvalue = [0.16, 0.84]\nclass = alta qualidade'),
#  Text(332.08246753246755, 125.44615384615385, 'sulphates <= -0.31\ngini = 0.42\nsamples = 0.8%\nvalue = [0.3, 0.7]\nclass = alta qualidade'),
#  Text(331.538961038961, 108.72, 'gini = 0.0\nsamples = 0.2%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(332.625974025974, 108.72, 'total sulfur dioxide <= -1.63\ngini = 0.49\nsamples = 0.6%\nvalue = [0.41, 0.59]\nclass = alta qualidade'),
#  Text(331.538961038961, 91.99384615384615, 'residual sugar <= -0.63\ngini = 0.44\nsamples = 0.2%\nvalue = [0.67, 0.33]\nclass = baixa qualidade'),
#  Text(330.99545454545455, 75.2676923076923, 'sulphates <= 0.33\ngini = 0.49\nsamples = 0.1%\nvalue = [0.43, 0.57]\nclass = alta qualidade'),
#  Text(330.451948051948, 58.541538461538465, 'alcohol <= 1.5\ngini = 0.38\nsamples = 0.1%\nvalue = [0.75, 0.25]\nclass = baixa qualidade'),
#  Text(329.90844155844155, 41.81538461538463, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(330.99545454545455, 41.81538461538463, 'gini = 0.0\nsamples = 0.0%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(331.538961038961, 58.541538461538465, 'gini = 0.0\nsamples = 0.1%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(332.08246753246755, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(333.712987012987, 91.99384615384615, 'citric acid <= -0.26\ngini = 0.36\nsamples = 0.3%\nvalue = [0.24, 0.76]\nclass = alta qualidade'),
#  Text(333.1694805194805, 75.2676923076923, 'alcohol <= 1.05\ngini = 0.13\nsamples = 0.3%\nvalue = [0.07, 0.93]\nclass = alta qualidade'),
#  Text(332.625974025974, 58.541538461538465, 'gini = 0.0\nsamples = 0.0%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(333.712987012987, 58.541538461538465, 'gini = 0.0\nsamples = 0.3%\nvalue = [0.0, 1.0]\nclass = alta qualidade'),
#  Text(334.2564935064935, 75.2676923076923, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]\nclass = baixa qualidade'),
#  Text(333.1694805194805, 125.44615384615385, 'gini = 0.0\nsamples = 0.7%\nvalue = [0.0, 1.0]\nclass = alta qualidade')]
