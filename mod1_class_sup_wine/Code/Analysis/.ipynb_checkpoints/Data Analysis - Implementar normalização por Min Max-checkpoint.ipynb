# %% [markdown]
# # Reefetuar as análises com a normalização Min Max
#
# ## Definição de pronto
#
# ### Dados preparados no ambiente
#
# ## Definição de entregue
#
# ### Notebook fazendo a avaliação

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as sklpp

pd.set_option("display.precision", 4)

df_wine = pd.read_parquet("../../Data/Processed/wine/df_wine.parquet")

# %%
# Criando dataframe normalizado'''

# Referência: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
#             https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame
#             https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02

# Usando MinMaxScaler para normalizar cada coluna
min_max_scaler = sklpp.MinMaxScaler()

df_wine_normalizado = min_max_scaler.fit_transform(df_wine)
df_wine_normalizado = pd.DataFrame(df_wine_normalizado)

# scikit learn retira as colunas do dataframe modificado. Colocando-as de volta
df_wine_normalizado.columns = df_wine.columns

# visualização da normalização
df_wine_normalizado.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         0.2975            0.4133       0.0000          0.0199     0.1113
# 1         0.3306            0.5333       0.0000          0.0307     0.1478
# 2         0.3306            0.4533       0.0241          0.0261     0.1379
# 3         0.6116            0.1333       0.3373          0.0199     0.1096
# 4         0.2975            0.4133       0.0000          0.0199     0.1113
#
#    free sulfur dioxide  total sulfur dioxide  density      pH  sulphates  \
# 0               0.0347                0.0645   0.2061  0.6124     0.1910
# 1               0.0833                0.1406   0.1868  0.3721     0.2584
# 2               0.0486                0.1106   0.1907  0.4186     0.2416
# 3               0.0556                0.1244   0.2099  0.3411     0.2022
# 4               0.0347                0.0645   0.2061  0.6124     0.1910
#
#    alcohol  quality  type
# 0   0.2029   0.3333   1.0
# 1   0.2609   0.3333   1.0
# 2   0.2609   0.3333   1.0
# 3   0.2609   0.5000   1.0
# 4   0.2029   0.3333   1.0

# %% [markdown]
# **Podemos observar uma grande redução na diferença das faixas dinâmicas das variáveis em relação aos dados não normalizados. Por exemplo, a variável total sulfur dioxide que apresentava, dependendo da variável de comparação, até 4 ordens de grandeza de diferença, após a normalização não há diferença de ordem de grandeza.**

# %% [markdown]
# ## Refazendo as análises

# %%
# Estatísticas Gerais

df_wine_normalizado.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      6497.0000         6497.0000    6497.0000       6497.0000
# mean          0.2823            0.1731       0.1919          0.0743
# std           0.1071            0.1098       0.0875          0.0730
# min           0.0000            0.0000       0.0000          0.0000
# 25%           0.2149            0.1000       0.1506          0.0184
# 50%           0.2645            0.1400       0.1867          0.0368
# 75%           0.3223            0.2133       0.2349          0.1150
# max           1.0000            1.0000       1.0000          1.0000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  6497.0000            6497.0000             6497.0000  6497.0000
# mean      0.0781               0.1025                0.2529     0.1463
# std       0.0582               0.0616                0.1302     0.0578
# min       0.0000               0.0000                0.0000     0.0000
# 25%       0.0482               0.0556                0.1636     0.1008
# 50%       0.0631               0.0972                0.2581     0.1500
# 75%       0.0930               0.1389                0.3456     0.1905
# max       1.0000               1.0000                1.0000     1.0000
#
#               pH  sulphates    alcohol    quality       type
# count  6497.0000  6497.0000  6497.0000  6497.0000  6497.0000
# mean      0.3864     0.1749     0.3611     0.4697     0.2461
# std       0.1246     0.0836     0.1729     0.1455     0.4308
# min       0.0000     0.0000     0.0000     0.0000     0.0000
# 25%       0.3023     0.1180     0.2174     0.3333     0.0000
# 50%       0.3798     0.1629     0.3333     0.5000     0.0000
# 75%       0.4651     0.2135     0.4783     0.5000     0.0000
# max       1.0000     1.0000     1.0000     1.0000     1.0000

# %%
# Avaliar a faixa dimâmica por variável

for (column, _ ) in df_wine_normalizado.items():
    print(f'{column} \t faixa dinâmica: \t {"{:.2f}".format(df_wine_normalizado[column].max() - df_wine_normalizado[column].min())}')
# Out:
# fixed acidity 	 faixa dinâmica: 	 1.00
# volatile acidity 	 faixa dinâmica: 	 1.00
# citric acid 	 faixa dinâmica: 	 1.00
# residual sugar 	 faixa dinâmica: 	 1.00
# chlorides 	 faixa dinâmica: 	 1.00
# free sulfur dioxide 	 faixa dinâmica: 	 1.00
# total sulfur dioxide 	 faixa dinâmica: 	 1.00
# density 	 faixa dinâmica: 	 1.00
# pH 	 faixa dinâmica: 	 1.00
# sulphates 	 faixa dinâmica: 	 1.00
# alcohol 	 faixa dinâmica: 	 1.00
# quality 	 faixa dinâmica: 	 1.00
# type 	 faixa dinâmica: 	 1.00

# %% [markdown]
# **Faixas dinâmicas igual a 1 esperadas dada a transformação de min-ma.**

# %%
# Histogramas com as distribuições das variáveis

# Referência: https://matplotlib.org/gallery/index.html

for (column, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado[column].plot.hist(bins=50, figsize=(15,5), legend=True);
    plt.legend(ncol = 1)
    plt.title(column)

# %% [markdown]
# **As distribuições não foram alteradas, como era esperado dado que a transformação min-max é linear. O comportamento linear é esperado para todas as características (pdf, correlações, etc)**

# %%
# Utilizar KDE - Kernel Density Estimate

# Referência: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.kde.html

for (column, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado[column].plot.kde(figsize=(15,5), legend=True);
    plt.legend(ncol = 1)
    plt.title(column)

# %%
# Correlação entre as variáveis

df_wine_normalizado.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                1.0000            0.2190       0.3244
# volatile acidity             0.2190            1.0000      -0.3780
# citric acid                  0.3244           -0.3780       1.0000
# residual sugar              -0.1120           -0.1960       0.1425
# chlorides                    0.2982            0.3771       0.0390
# free sulfur dioxide         -0.2827           -0.3526       0.1331
# total sulfur dioxide        -0.3291           -0.4145       0.1952
# density                      0.4589            0.2713       0.0962
# pH                          -0.2527            0.2615      -0.3298
# sulphates                    0.2996            0.2260       0.0562
# alcohol                     -0.0955           -0.0376      -0.0105
# quality                     -0.0767           -0.2657       0.0855
# type                         0.4867            0.6530      -0.1874
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity                -0.1120     0.2982              -0.2827
# volatile acidity             -0.1960     0.3771              -0.3526
# citric acid                   0.1425     0.0390               0.1331
# residual sugar                1.0000    -0.1289               0.4029
# chlorides                    -0.1289     1.0000              -0.1950
# free sulfur dioxide           0.4029    -0.1950               1.0000
# total sulfur dioxide          0.4955    -0.2796               0.7209
# density                       0.5525     0.3626               0.0257
# pH                           -0.2673     0.0447              -0.1459
# sulphates                    -0.1859     0.3956              -0.1885
# alcohol                      -0.3594    -0.2569              -0.1798
# quality                      -0.0370    -0.2007               0.0555
# type                         -0.3488     0.5127              -0.4716
#
#                       total sulfur dioxide  density      pH  sulphates  \
# fixed acidity                      -0.3291   0.4589 -0.2527     0.2996
# volatile acidity                   -0.4145   0.2713  0.2615     0.2260
# citric acid                         0.1952   0.0962 -0.3298     0.0562
# residual sugar                      0.4955   0.5525 -0.2673    -0.1859
# chlorides                          -0.2796   0.3626  0.0447     0.3956
# free sulfur dioxide                 0.7209   0.0257 -0.1459    -0.1885
# total sulfur dioxide                1.0000   0.0324 -0.2384    -0.2757
# density                             0.0324   1.0000  0.0117     0.2595
# pH                                 -0.2384   0.0117  1.0000     0.1921
# sulphates                          -0.2757   0.2595  0.1921     1.0000
# alcohol                            -0.2657  -0.6867  0.1212    -0.0030
# quality                            -0.0414  -0.3059  0.0195     0.0385
# type                               -0.7004   0.3906  0.3291     0.4872
#
#                       alcohol  quality    type
# fixed acidity         -0.0955  -0.0767  0.4867
# volatile acidity      -0.0376  -0.2657  0.6530
# citric acid           -0.0105   0.0855 -0.1874
# residual sugar        -0.3594  -0.0370 -0.3488
# chlorides             -0.2569  -0.2007  0.5127
# free sulfur dioxide   -0.1798   0.0555 -0.4716
# total sulfur dioxide  -0.2657  -0.0414 -0.7004
# density               -0.6867  -0.3059  0.3906
# pH                     0.1212   0.0195  0.3291
# sulphates             -0.0030   0.0385  0.4872
# alcohol                1.0000   0.4443 -0.0330
# quality                0.4443   1.0000 -0.1193
# type                  -0.0330  -0.1193  1.0000

# %%
# Scatter Plot

# Referência: https://seaborn.pydata.org/generated/seaborn.pairplot.html'''

import seaborn as sb
sb.pairplot(df_wine_normalizado)

# %%
# Box Plot
# Referência: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html'''

for (column_name, _ ) in df_wine_normalizado.items():
    plt.figure()
    df_wine_normalizado.boxplot(column = column_name)
    plt.title(column_name)
